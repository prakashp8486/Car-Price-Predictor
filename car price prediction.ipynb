# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('file:///C:/Users/prakash/Documents/MACHINE%20LEARNING/FINAL%20PROJECTS/CAMPUS%20X/Car%20Price%20Predictor/quikr_car.csv')
data
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 887                                      Ta       Tara  zest       3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#      kms_driven fuel_type
# 0    45,000 kms    Petrol
# ...

# %%
data.isnull().sum()
# Out:
# name           0
# company        0
# year           0
# Price          0
# kms_driven    52
# fuel_type     55
# dtype: int64

# %%
data.describe()
# Out:
#               name company  year          Price  kms_driven fuel_type
# count          892     892   892            892         840       837
# unique         525      48    61            274         258         3
# top     Honda City  Maruti  2015  Ask For Price  45,000 kms    Petrol
# freq            13     235   117             35          30       440

# %%
data.name.value_counts()
# Out:
# Honda City                         13
# Honda Amaze                        11
# Maruti Suzuki Dzire                10
# Mahindra Scorpio S10                9
# Maruti Suzuki Alto 800 Lxi          9
#                                    ..
# Mahindra Bolero DI BSII             1
# Audi Q3 2.0 TDI quattro Premium     1
# Skoda Superb 1.8 TFSI AT            1
# BMW 5 Series 520d Sedan             1
# Chevrolet Sail 1.2 LT ABS           1
# Name: name, Length: 525, dtype: int64

# %%
data.dtypes
# Out:
# name          object
# company       object
# year          object
# Price         object
# kms_driven    object
# fuel_type     object
# dtype: object

# %%
data.dropna(axis=0,inplace=True)

# %%
data
# Out:
#                                        name   company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
# ..                                      ...       ...   ...            ...
# 883              Maruti Suzuki Ritz VXI ABS    Maruti  2011       2,70,000
# 885               Tata Indica V2 DLE BS III      Tata  2009       1,10,000
# 886                    Toyota Corolla Altis    Toyota  2009       3,00,000
# 888                     Tata Zest XM Diesel      Tata  2018       2,60,000
# 889                      Mahindra Quanto C8  Mahindra  2013       3,90,000
#
#        kms_driven fuel_type
# 0      45,000 kms    Petrol
# ...

# %%
 data.fuel_type.value_counts()
# Out:
# Petrol    440
# Diesel    395
# LPG         2
# Name: fuel_type, dtype: int64

# %%
data.head()
# Out:
#                                      name   company  year          Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
#
#    kms_driven fuel_type
# 0  45,000 kms    Petrol
# 1      40 kms    Diesel
# 2  22,000 kms    Petrol
# 3  28,000 kms    Petrol
# 4  36,000 kms    Diesel

# %%
data.name.value_counts()
# Out:
# Honda City                             13
# Honda Amaze                            11
# Maruti Suzuki Dzire                    10
# Maruti Suzuki Alto 800 Lxi              9
# Mahindra Scorpio S10                    9
#                                        ..
# Mahindra TUV300 T8                      1
# Honda Brio V MT                         1
# Renault Duster 85 PS RxL Explore LE     1
# Hyundai i20 Magna O 1.2                 1
# Tata Zest XM Diesel                     1
# Name: name, Length: 473, dtype: int64

# %%
data.company.value_counts()
# Out:
# Maruti        229
# Hyundai       143
# Mahindra       99
# Tata           67
# Honda          60
# Toyota         38
# Chevrolet      34
# Renault        34
# Ford           31
# Volkswagen     20
# Skoda          13
# Audi           11
# Datsun          8
# Mini            8
# BMW             8
# Mitsubishi      6
# Nissan          6
# Mercedes        6
# Fiat            4
# Force           4
# Hindustan       3
# Jaguar          2
# Land            1
# Jeep            1
# Volvo           1
# Name: company, dtype: int64

# %%
data.head()
# Out:
#                                      name   company  year          Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
#
#    kms_driven fuel_type
# 0  45,000 kms    Petrol
# 1      40 kms    Diesel
# 2  22,000 kms    Petrol
# 3  28,000 kms    Petrol
# 4  36,000 kms    Diesel

# %%
data.isnull().sum()
# Out:
# name          0
# company       0
# year          0
# Price         0
# kms_driven    0
# fuel_type     0
# dtype: int64

# %% [markdown]
# # to do

# %% [raw]
# 1) remove nan values
# 2) year to int
# 3) price to int
# 4) kms to int
# 5) apply encoding on name column
# 6) apply encoding on company column
# 7) keep only 4 words in name column per record

# %%
#converting year type to int

# %%
data.year.value_counts()
# Out:
# 2015    117
# 2013     94
# 2014     92
# 2016     76
# 2012     75
# 2011     60
# 2009     55
# 2017     54
# 2010     44
# 2018     34
# 2006     22
# 2019     22
# 2007     19
# 2008     16
# 2005     13
# 2003     13
# 2004     12
# 2000      7
# 2002      5
# 2001      5
# 1995      2
# Name: year, dtype: int64

# %%
data.year=data.year.astype('int')

# %%
# converting Price column type to float

# %%
data.Price.value_counts()
# Out:
# Ask For Price    21
# 2,50,000         16
# 3,50,000         12
# 4,00,000         11
# 1,30,000         11
#                  ..
# 7,49,999          1
# 11,30,000         1
# 10,74,999         1
# 3,24,999          1
# 5,00,001          1
# Name: Price, Length: 273, dtype: int64

# %%
data.Price.describe()
# Out:
# count               837
# unique              273
# top       Ask For Price
# freq                 21
# Name: Price, dtype: object

# %%
data.Price
# Out:
# 0             80,000
# 1           4,25,000
# 2      Ask For Price
# 3           3,25,000
# 4           5,75,000
#            ...
# 883         2,70,000
# 885         1,10,000
# 886         3,00,000
# 888         2,60,000
# 889         3,90,000
# Name: Price, Length: 837, dtype: object

# %%
data[data.Price=='Ask For Price']
# Out:
#                                           name     company  year  \
# 2                   Maruti Suzuki Alto 800 Vxi      Maruti  2018
# 5             Ford EcoSport Titanium 1.5L TDCi        Ford  2015
# 138                 Maruti Suzuki Alto 800 Lxi      Maruti  2018
# 295                    Maruti Suzuki Swift LDi      Maruti  2010
# 304                         Tata Indica eV2 LS        Tata  2017
# 388                 Maruti Suzuki Alto 800 Lxi      Maruti  2018
# 449     Maruti Suzuki Zen Estilo LXI Green CNG      Maruti  2011
# 503                Hyundai Xcent Base 1.1 CRDi     Hyundai  2015
# 511                        Hyundai Xcent S 1.2     Hyundai  2015
# 524                        Toyota Innova 2.0 V      Toyota  2009
# 567                         Datsun Go Plus T O      Datsun  2016
# 613                 Mahindra KUV100 K8 D 6 STR    Mahindra  2018
# 619                 Maruti Suzuki Alto LX BSII      Maruti  2002
# ...

# %%
data.Price=data.Price.replace('Ask For Price','0')
data.Price.value_counts()
# Out:
# 0            21
# 2,50,000     16
# 3,50,000     12
# 4,00,000     11
# 1,30,000     11
#              ..
# 7,49,999      1
# 11,30,000     1
# 10,74,999     1
# 3,24,999      1
# 5,00,001      1
# Name: Price, Length: 273, dtype: int64

# %%
data.Price.value_counts()
# Out:
# 0            21
# 2,50,000     16
# 3,50,000     12
# 4,00,000     11
# 1,30,000     11
#              ..
# 7,49,999      1
# 11,30,000     1
# 10,74,999     1
# 3,24,999      1
# 5,00,001      1
# Name: Price, Length: 273, dtype: int64

# %%
data.Price=data.Price.str.replace(',','')

# %%
data.Price=data.Price.astype('int64')

# %%
data.Price=data.Price.replace(0,data.Price.median())

# %%
data.head()
# Out:
#                                      name   company  year   Price  kms_driven  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000  45,000 kms
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006  425000      40 kms
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  290000  22,000 kms
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000  28,000 kms
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000  36,000 kms
#
#   fuel_type
# 0    Petrol
# 1    Diesel
# 2    Petrol
# 3    Petrol
# 4    Diesel

# %%
# converting kms_driven colmn

# %%
data.kms_driven.value_counts()
# Out:
# 45,000 kms      30
# 35,000 kms      30
# 55,000 kms      25
# 50,000 kms      23
# 20,000 kms      22
#                 ..
# 59,466 kms       1
# 25,500 kms       1
# 44,005 kms       1
# 2,110 kms        1
# 1,32,000 kms     1
# Name: kms_driven, Length: 256, dtype: int64

# %%
data.kms_driven.describe()
# Out:
# count            837
# unique           256
# top       45,000 kms
# freq              30
# Name: kms_driven, dtype: object

# %%
data.kms_driven=data.kms_driven.str.replace('kms','')

# %%
data.kms_driven=data.kms_driven.str.replace(',','')

# %%
data.kms_driven=data.kms_driven.astype('int64')

# %%
data.describe()
# Out:
#               year         Price     kms_driven
# count   837.000000  8.370000e+02     837.000000
# mean   2012.513740  4.086638e+05   46034.457587
# std       4.028174  4.695647e+05   34483.283332
# min    1995.000000  3.000000e+04       0.000000
# 25%    2010.000000  1.780000e+05   25000.000000
# 50%    2013.000000  2.900000e+05   41000.000000
# 75%    2015.000000  4.899990e+05   56450.000000
# max    2019.000000  8.500003e+06  400000.000000

# %%
data.head()
# Out:
#                                      name   company  year   Price  kms_driven  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000       45000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006  425000          40
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  290000       22000
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000       28000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000       36000
#
#   fuel_type
# 0    Petrol
# 1    Diesel
# 2    Petrol
# 3    Petrol
# 4    Diesel

# %%
# slicing name column elements

# %%
data.name=data.name.str.split(' ').str.slice(0,3).str.join(' ')

# %%
data.head()
# Out:
#                      name   company  year   Price  kms_driven fuel_type
# 0     Hyundai Santro Xing   Hyundai  2007   80000       45000    Petrol
# 1     Mahindra Jeep CL550  Mahindra  2006  425000          40    Diesel
# 2      Maruti Suzuki Alto    Maruti  2018  290000       22000    Petrol
# 3       Hyundai Grand i10   Hyundai  2014  325000       28000    Petrol
# 4  Ford EcoSport Titanium      Ford  2014  575000       36000    Diesel

# %% [markdown]
# # apply

# %% [raw]
# one hot encoder= name,company,fule_type

# %%
data.fuel_type.value_counts()
# Out:
# Petrol    440
# Diesel    395
# LPG         2
# Name: fuel_type, dtype: int64

# %%
x=data.drop('Price',axis=1)

# %%
y=data.Price

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=.2)

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LinearRegression

# %%
ohe=OneHotEncoder()

# %%
ohe.fit(x[['name','company','fuel_type']])
# Out:
# OneHotEncoder()

# %%
ohe.categories_
# Out:
# [array(['Audi A3 Cabriolet', 'Audi A4 1.8', 'Audi A4 2.0', 'Audi A6 2.0',
#         'Audi A8', 'Audi Q3 2.0', 'Audi Q5 2.0', 'Audi Q7', 'BMW 3 Series',
#         'BMW 5 Series', 'BMW 7 Series', 'BMW X1', 'BMW X1 sDrive20d',
#         'BMW X1 xDrive20d', 'Chevrolet Beat', 'Chevrolet Beat Diesel',
#         'Chevrolet Beat LS', 'Chevrolet Beat LT', 'Chevrolet Beat PS',
#         'Chevrolet Cruze LTZ', 'Chevrolet Enjoy', 'Chevrolet Enjoy 1.4',
#         'Chevrolet Sail 1.2', 'Chevrolet Sail UVA', 'Chevrolet Spark',
#         'Chevrolet Spark 1.0', 'Chevrolet Spark LS', 'Chevrolet Spark LT',
#         'Chevrolet Tavera LS', 'Chevrolet Tavera Neo', 'Datsun GO T',
#         'Datsun Go Plus', 'Datsun Redi GO', 'Fiat Linea Emotion',
#         'Fiat Petra ELX', 'Fiat Punto Emotion', 'Force Motors Force',
#         'Force Motors One', 'Ford EcoSport', 'Ford EcoSport Ambiente',
#         'Ford EcoSport Titanium', 'Ford EcoSport Trend',
# ...

# %%
column_trans=make_column_transformer((OneHotEncoder(categories=ohe.categories_),['name','company','fuel_type']),remainder='passthrough')

# %%
lr=LinearRegression()

# %%
pipe=make_pipeline(column_trans,lr)

# %%
pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Audi A3 Cabriolet', 'Audi A4 1.8', 'Audi A4 2.0', 'Audi A6 2.0',
#        'Audi A8', 'Audi Q3 2.0', 'Audi Q5 2.0', 'Audi Q7', 'BMW 3 Series',
#        'BMW 5 Series', 'BMW 7 Series', 'BMW X1', 'BMW X1 sDrive20d',
#        'BMW X1 xDrive20d', 'Chevrolet Beat', 'Chevrolet Beat...
#                                                                             array(['Audi', 'BMW', 'Chevrolet', 'Datsun', 'Fiat', 'Force', 'Ford',
#        'Hindustan', 'Honda', 'Hyundai', 'Jaguar', 'Jeep', 'Land',
#        'Mahindra', 'Maruti', 'Mercedes', 'Mini', 'Mitsubishi', 'Nissan',
#        'Renault', 'Skoda', 'Tata', 'Toyota', 'Volkswagen', 'Volvo'],
#       dtype=object),
# ...

# %%
pipe.score(x_test,y_test)
# Out:
# -0.18244844115156678

# %%
# loop to get random x_train ,x_test,y_train,y_test
liss=[]
for index in range(1000):
    x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=.2)
    lr=LinearRegression()
    pipe=make_pipeline(column_trans,lr)
    pipe.fit(x_train,y_train)
    liss.append(pipe.score(x_test,y_test)*100)
    print(pipe.score(x_test,y_test)*100,index)
# Out:
# -10.819078782160151 0
# 75.66842347600019 1
# 73.4348938262779 2
# 69.09243150129265 3
# 66.49027864747907 4
# 59.75458606286945 5
# -1.8466323963613362 6
# 22.593738533454445 7
# 65.74471614565631 8
# 65.01698238374122 9
# 24.90039463956669 10
# -12.326586919401983 11
# 79.22856980428361 12
# 61.29411419659332 13
# -4.708237371456581 14
# 22.93451938158637 15
# 24.55128995055762 16
# 0.7391715441622537 17
# 74.61386028721928 18
# 4.26615040550562 19
# 60.10203587537202 20
# -14.012180008091768 21
# 81.92839289824776 22
# -9.022212887347436 23
# -1.8435130432978175 24
# 13.919312878029155 25
# 63.03447257652086 26
# 65.21867343849134 27
# 73.63648000610327 28
# 71.9291697718721 29
# 69.72397848350937 30
# 56.237617277823794 31
# 69.89764443545174 32
# 7.426845058654252 33
# 64.46991755795382 34
# 24.22516751213418 35
# 28.06894933762657 36
# -26.214811872687417 37
# -12.646685587774353 38
# 70.6353784055365 39
# 21.753020479723737 40
# 59.35363817512209 41
# 63.01938414133333 42
# ...

# %%
data.head()
# Out:
#                      name   company  year   Price  kms_driven fuel_type
# 0     Hyundai Santro Xing   Hyundai  2007   80000       45000    Petrol
# 1     Mahindra Jeep CL550  Mahindra  2006  425000          40    Diesel
# 2      Maruti Suzuki Alto    Maruti  2018  290000       22000    Petrol
# 3       Hyundai Grand i10   Hyundai  2014  325000       28000    Petrol
# 4  Ford EcoSport Titanium      Ford  2014  575000       36000    Diesel

# %%
from scipy import stats

# %%
sorted(stats.zscore(data.Price),reverse=True)
# Out:
# [17.241876601353063,
#  5.734982290551542,
#  5.3088012565483576,
#  5.095710739546765,
#  4.222039619840234,
#  3.7958585858370486,
#  3.604077120535615,
#  3.3909866035340226,
#  3.1778960865324297,
#  3.158954470476158,
#  3.158954470476158,
#  3.158954470476158,
#  3.158954470476158,
#  3.158954470476158,
#  3.158954470476158,
#  3.158954470476158,
#  3.158954470476158,
#  3.0713508280316333,
#  2.8049876817796426,
#  2.5386245355276515,
#  2.5364936303576355,
#  2.410770225326696,
#  2.378806647776457,
#  2.378806647776457,
#  2.346843070226218,
#  2.3255340185260587,
#  2.3234031133560427,
#  2.3234031133560427,
#  2.3042249668258994,
#  2.2722613892756605,
#  2.2722613892756605,
#  2.1124435015244662,
#  2.00589824302367,
#  1.8972220793528574,
#  1.8972220793528574,
#  1.7395350967716787,
#  1.6862624675212805,
#  1.6862624675212805,
#  1.6862624675212805,
#  1.579717209020484,
#  1.5370991056201657,
#  1.4198993212692896,
#  1.4198971903641195,
#  1.3985902695691304,
# ...

# %%
data['z_score_PRICE'] =stats.zscore(data.Price)
data.head()
# Out:
#                      name   company  year   Price  kms_driven fuel_type  \
# 0     Hyundai Santro Xing   Hyundai  2007   80000       45000    Petrol
# 1     Mahindra Jeep CL550  Mahindra  2006  425000          40    Diesel
# 2      Maruti Suzuki Alto    Maruti  2018  290000       22000    Petrol
# 3       Hyundai Grand i10   Hyundai  2014  325000       28000    Petrol
# 4  Ford EcoSport Titanium      Ford  2014  575000       36000    Diesel
#
#    z_score_PRICE
# 0      -0.700351
# 1       0.034811
# 2      -0.252861
# 3      -0.178280
# 4       0.354447

# %%
data['z_score_kms_driven'] =stats.zscore(data.kms_driven)
data.head()
# Out:
#                      name   company  year   Price  kms_driven fuel_type  \
# 0     Hyundai Santro Xing   Hyundai  2007   80000       45000    Petrol
# 1     Mahindra Jeep CL550  Mahindra  2006  425000          40    Diesel
# 2      Maruti Suzuki Alto    Maruti  2018  290000       22000    Petrol
# 3       Hyundai Grand i10   Hyundai  2014  325000       28000    Petrol
# 4  Ford EcoSport Titanium      Ford  2014  575000       36000    Diesel
#
#    z_score_PRICE  z_score_kms_driven
# 0      -0.700351           -0.030017
# 1       0.034811           -1.334616
# 2      -0.252861           -0.697405
# 3      -0.178280           -0.523304
# 4       0.354447           -0.291169

# %%
drop_price=data[(data.z_score_PRICE<-3)|(data.z_score_PRICE>=3) ].index
drop_price
# Out:
# Int64Index([ 73,  79, 189, 231, 232, 249, 269, 297, 298, 300, 510, 562, 667,
#             668, 678, 692, 719, 838],
#            dtype='int64')

# %%
drop_kms_driven=data[(data.z_score_kms_driven<-3)|(data.z_score_kms_driven>=3)].index
drop_kms_driven
# Out:
# Int64Index([139, 183, 237, 238, 283, 303, 313, 362, 379, 443, 503, 553, 589,
#             612, 621, 690, 790, 873],
#            dtype='int64')

# %%
data.drop(index=drop_price,axis=0,inplace=True)

# %%
data.drop(index=drop_kms_driven,axis=0,inplace=True)

# %%
data.shape
# Out:
# (801, 8)

# %%
data
# Out:
#                        name   company  year   Price  kms_driven fuel_type  \
# 0       Hyundai Santro Xing   Hyundai  2007   80000       45000    Petrol
# 1       Mahindra Jeep CL550  Mahindra  2006  425000          40    Diesel
# 2        Maruti Suzuki Alto    Maruti  2018  290000       22000    Petrol
# 3         Hyundai Grand i10   Hyundai  2014  325000       28000    Petrol
# 4    Ford EcoSport Titanium      Ford  2014  575000       36000    Diesel
# ..                      ...       ...   ...     ...         ...       ...
# 883      Maruti Suzuki Ritz    Maruti  2011  270000       50000    Petrol
# 885          Tata Indica V2      Tata  2009  110000       30000    Diesel
# 886    Toyota Corolla Altis    Toyota  2009  300000      132000    Petrol
# 888            Tata Zest XM      Tata  2018  260000       27000    Diesel
# 889      Mahindra Quanto C8  Mahindra  2013  390000       40000    Diesel
#
#      z_score_PRICE  z_score_kms_driven
# 0        -0.700351           -0.030017
# ...

# %%
data.drop(['z_score_PRICE','z_score_kms_driven'],axis=1,inplace=True)

# %%
data.head()
# Out:
#                      name   company  year   Price  kms_driven fuel_type
# 0     Hyundai Santro Xing   Hyundai  2007   80000       45000    Petrol
# 1     Mahindra Jeep CL550  Mahindra  2006  425000          40    Diesel
# 2      Maruti Suzuki Alto    Maruti  2018  290000       22000    Petrol
# 3       Hyundai Grand i10   Hyundai  2014  325000       28000    Petrol
# 4  Ford EcoSport Titanium      Ford  2014  575000       36000    Diesel

# %%
x=data.drop('Price',axis=1)

# %%
y=data.Price

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=.2)

# %%
ohe=OneHotEncoder()

# %%
ohe.fit(x[['name','company','fuel_type']])
# Out:
# OneHotEncoder()

# %%
column_trans=make_column_transformer((OneHotEncoder(categories=ohe.categories_),['name','company','fuel_type']),remainder='passthrough')

# %%
lr=LinearRegression()

# %%
pipe=make_pipeline(column_trans,lr)

# %%
pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Audi A4 1.8', 'Audi A4 2.0', 'Audi A6 2.0', 'Audi A8',
#        'Audi Q3 2.0', 'Audi Q7', 'BMW 3 Series', 'BMW 5 Series',
#        'BMW 7 Series', 'BMW X1', 'BMW X1 sDrive20d', 'BMW X1 xDrive20d',
#        'Chevrolet Beat', 'Chevrolet Beat Diesel', 'Chevrolet Beat LS',
#        'Che...
#        'Volkswagen Vento Konekt'], dtype=object),
#                                                                             array(['Audi', 'BMW', 'Chevrolet', 'Datsun', 'Fiat', 'Force', 'Ford',
#        'Hindustan', 'Honda', 'Hyundai', 'Jeep', 'Mahindra', 'Maruti',
#        'Mercedes', 'Mitsubishi', 'Nissan', 'Renault', 'Skoda', 'Tata',
#        'Toyota', 'Volkswagen'], dtype=object),
# ...

# %%
pipe.score(x_test,y_test)
# Out:
# 0.712812812594481

# %%
# loop to get random x_train ,x_test,y_train,y_test
liss=[]
for index in range(100):
    x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=.2)
    lr=LinearRegression()
    pipe=make_pipeline(column_trans,lr)
    pipe.fit(x_train,y_train)
    liss.append(pipe.score(x_test,y_test)*100)
    print(pipe.score(x_test,y_test)*100,index)
# Out:
# 73.04987302340355 0
# 76.05223564167582 1
# 73.49410302620396 2
# 64.35263308489027 3
# 65.17824162508548 4
# 75.58434118369829 5
# 72.40116338981882 6
# 64.46027014330379 7
# 72.84668654761171 8
# 75.66498307610142 9
# 79.99455123743218 10
# 64.83981380798762 11
# 63.79910041878097 12
# 50.95576454353565 13
# 55.41516405572591 14
# 74.48089453825646 15
# 62.55981313034227 16
# 79.53796354792601 17
# 60.40226820176314 18
# 75.83287853188514 19
# 76.15825901898724 20
# 59.82413050579621 21
# 65.72592845729616 22
# 67.18252374043057 23
# 72.03582165344872 24
# 75.83430542692547 25
# 71.29021151751596 26
# 64.09280555966679 27
# 65.07852822437464 28
# 64.15050563212489 29
# 79.25478219439076 30
# 65.17155455270667 31
# 71.34534998986992 32
# 61.647211033328055 33
# 70.23975452817498 34
# 69.74295837958482 35
# 52.643180959478045 36
# 67.32578805926263 37
# 67.09943143860706 38
# 72.29968189110949 39
# 68.59355579400284 40
# 61.38039865626188 41
# 79.36090423090191 42
# ...

# %%
liss[np.argmax(liss)]
# Out:
# 80.07776655561644

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=.2,random_state=np.argmax(liss))
lr=LinearRegression()
pipe=make_pipeline(column_trans,lr)
pipe.fit(x_train,y_train)
pipe.predict(x_test)
print(pipe.score(x_test,y_test)*100)
# Out:
# 65.735736464703

# %%
np.argmax(liss)
# Out:
# 85

# %%
import pickle

# %%
pickle.dump(pipe,open('LinearRegressionModel.pkl','wb'))

# %%
x.head()
# Out:
#                      name   company  year  kms_driven fuel_type
# 0     Hyundai Santro Xing   Hyundai  2007       45000    Petrol
# 1     Mahindra Jeep CL550  Mahindra  2006          40    Diesel
# 2      Maruti Suzuki Alto    Maruti  2018       22000    Petrol
# 3       Hyundai Grand i10   Hyundai  2014       28000    Petrol
# 4  Ford EcoSport Titanium      Ford  2014       36000    Diesel

# %%
pipe.predict(pd.DataFrame([['Maruti Suzuki Swift','Maruti',2019,1000,'Petrol']],columns=['name','company','year','kms_driven','fuel_type']))
# Out:
# array([425889.88923205])

# %%
data.head()
# Out:
#                      name   company  year   Price  kms_driven fuel_type
# 0     Hyundai Santro Xing   Hyundai  2007   80000       45000    Petrol
# 1     Mahindra Jeep CL550  Mahindra  2006  425000          40    Diesel
# 2      Maruti Suzuki Alto    Maruti  2018  290000       22000    Petrol
# 3       Hyundai Grand i10   Hyundai  2014  325000       28000    Petrol
# 4  Ford EcoSport Titanium      Ford  2014  575000       36000    Diesel

# %%
data.to_csv('cleaned_data.csv')

# %%
data.tail()
# Out:
#                      name   company  year   Price  kms_driven fuel_type
# 883    Maruti Suzuki Ritz    Maruti  2011  270000       50000    Petrol
# 885        Tata Indica V2      Tata  2009  110000       30000    Diesel
# 886  Toyota Corolla Altis    Toyota  2009  300000      132000    Petrol
# 888          Tata Zest XM      Tata  2018  260000       27000    Diesel
# 889    Mahindra Quanto C8  Mahindra  2013  390000       40000    Diesel

# %%
data.shape
# Out:
# (801, 6)

# %%
data.reset_index(inplace=True)

# %%
data.head()
# Out:
#    index                    name   company  year   Price  kms_driven fuel_type
# 0      0     Hyundai Santro Xing   Hyundai  2007   80000       45000    Petrol
# 1      1     Mahindra Jeep CL550  Mahindra  2006  425000          40    Diesel
# 2      2      Maruti Suzuki Alto    Maruti  2018  290000       22000    Petrol
# 3      3       Hyundai Grand i10   Hyundai  2014  325000       28000    Petrol
# 4      4  Ford EcoSport Titanium      Ford  2014  575000       36000    Diesel

# %%
data.drop('index',axis=1,inplace=True)

# %%
data.tail()
# Out:
#                      name   company  year   Price  kms_driven fuel_type
# 796    Maruti Suzuki Ritz    Maruti  2011  270000       50000    Petrol
# 797        Tata Indica V2      Tata  2009  110000       30000    Diesel
# 798  Toyota Corolla Altis    Toyota  2009  300000      132000    Petrol
# 799          Tata Zest XM      Tata  2018  260000       27000    Diesel
# 800    Mahindra Quanto C8  Mahindra  2013  390000       40000    Diesel

# %%
data.to_csv('cleaned_data.csv')
